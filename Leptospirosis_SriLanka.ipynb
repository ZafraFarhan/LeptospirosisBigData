# %% [markdown]
# <a href="https://colab.research.google.com/github/ZafraFarhan/LeptospirosisBigData/blob/main/Leptospirosis_SriLanka.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
#  **04**

# %%
# !pip install requests beautifulsoup4 pdfplumber
# Out:
# Requirement already satisfied: requests in /usr/local/lib/python3.10/dist-packages (2.32.3)
# Requirement already satisfied: beautifulsoup4 in /usr/local/lib/python3.10/dist-packages (4.12.3)
# Requirement already satisfied: pdfplumber in /usr/local/lib/python3.10/dist-packages (0.11.3)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests) (2024.7.4)
# Requirement already satisfied: soupsieve>1.2 in /usr/local/lib/python3.10/dist-packages (from beautifulsoup4) (2.5)
# Requirement already satisfied: pdfminer.six==20231228 in /usr/local/lib/python3.10/dist-packages (from pdfplumber) (20231228)
# Requirement already satisfied: Pillow>=9.1 in /usr/local/lib/python3.10/dist-packages (from pdfplumber) (9.4.0)
# Requirement already satisfied: pypdfium2>=4.18.0 in /usr/local/lib/python3.10/dist-packages (from pdfplumber) (4.30.0)
# Requirement already satisfied: cryptography>=36.0.0 in /usr/local/lib/python3.10/dist-packages (from pdfminer.six==20231228->pdfplumber) (42.0.8)
# Requirement already satisfied: cffi>=1.12 in /usr/local/lib/python3.10/dist-packages (from cryptography>=36.0.0->pdfminer.six==20231228->pdfplumber) (1.16.0)
# Requirement already satisfied: pycparser in /usr/local/lib/python3.10/dist-packages (from cffi>=1.12->cryptography>=36.0.0->pdfminer.six==20231228->pdfplumber) (2.22)

# %%
import requests
from bs4 import BeautifulSoup
import os

# Define the URL of the webpage
url = 'https://www.epid.gov.lk/weekly-epidemiological-report/weekly-epidemiological-report'

# Define the directory to save downloaded PDFs
output_dir = 'pdfs'
os.makedirs(output_dir, exist_ok=True)

def download_first_pdf(url, output_dir):
    response = requests.get(url)
    soup = BeautifulSoup(response.text, 'html.parser')

    # Find the first accordion
    accordion = soup.find(class_='accordions')

    downloaded_pdfs = []

    if accordion:
        # Find the content within the first accordion
        content = accordion.find(class_='content')
        if content:
            # Find the first product link within the content
            product = content.find('li', class_='product')
            if product:
                a_tag = product.find('a', href=True)
                if a_tag:
                    pdf_url = a_tag['href']
                    pdf_name = os.path.basename(pdf_url)
                    pdf_path = os.path.join(output_dir, pdf_name)

                    # Download the PDF
                    pdf_response = requests.get(pdf_url)
                    with open(pdf_path, 'wb') as file:
                        file.write(pdf_response.content)

                    print(f'Downloaded: {pdf_path}')
                    downloaded_pdfs.append(pdf_path)

    return downloaded_pdfs

pdf_paths1 = download_first_pdf(url, output_dir)
# Out:
# Downloaded: pdfs/en_66b1cf8a4ad9f_Vol_51_no_29-english.pdf

# %%
import requests
from bs4 import BeautifulSoup
import os

# Define the URL of the webpage
url = 'https://www.epid.gov.lk/weekly-epidemiological-report/weekly-epidemiological-report'

# Define the directory to save downloaded PDFs
output_dir = 'pdfs'
os.makedirs(output_dir, exist_ok=True)

def download_last_pdf(url, output_dir):
    response = requests.get(url)
    soup = BeautifulSoup(response.text, 'html.parser')

    # Find all accordions
    accordions = soup.find_all(class_='accordions')

    downloaded_pdfs = []

    for accordion in accordions:
        # Find all content within the accordion
        content = accordion.find(class_='content')
        if content:
            # Find all product links within the content
            products = content.find_all('li', class_='product')
            if products:
                # Get the last product link
                last_product = products[-1]
                a_tag = last_product.find('a', href=True)
                if a_tag:
                    pdf_url = a_tag['href']
                    pdf_name = os.path.basename(pdf_url)
                    pdf_path = os.path.join(output_dir, pdf_name)

                    # Download the PDF
                    pdf_response = requests.get(pdf_url)
                    with open(pdf_path, 'wb') as file:
                        file.write(pdf_response.content)

                    print(f'Downloaded: {pdf_path}')
                    downloaded_pdfs.append(pdf_path)

    return downloaded_pdfs

pdf_paths2 = download_last_pdf(url, output_dir)
# Out:
# Downloaded: pdfs/en_65b8d3689b762_Vol_51_no_01-english.pdf
# Downloaded: pdfs/en_640feff0076ea_Vol_50_no_01-english.pdf
# Downloaded: pdfs/vol_49_no_01-english.pdf
# Downloaded: pdfs/vol_48_no_01-english.pdf
# Downloaded: pdfs/vol_47_no_01-english.pdf
# Downloaded: pdfs/vol_46_no_01-english.pdf
# Downloaded: pdfs/vol_45_no_01-english.pdf
# Downloaded: pdfs/vol_44_no_01-english.pdf
# Downloaded: pdfs/vol_43_no_01-english.pdf
# Downloaded: pdfs/vol_42_no_01-english.pdf
# Downloaded: pdfs/vol_41_no_01-english.pdf
# Downloaded: pdfs/vol_40_no_01_english.pdf
# Downloaded: pdfs/Vol 39 NO 01 English.pdf
# Downloaded: pdfs/Vol 38 NO 01 English.pdf
# Downloaded: pdfs/vol_37_no_01_english.pdf
# Downloaded: pdfs/Vol_36_NO_01_English.pdf
# Downloaded: pdfs/vol_35_no_01_english.pdf
# Downloaded: pdfs/vol_34_no_01_english.pdf

# %%
pdf_paths = pdf_paths1 + pdf_paths2
print(pdf_paths)
# Out:
# ['pdfs/en_66b1cf8a4ad9f_Vol_51_no_29-english.pdf', 'pdfs/en_65b8d3689b762_Vol_51_no_01-english.pdf', 'pdfs/en_640feff0076ea_Vol_50_no_01-english.pdf', 'pdfs/vol_49_no_01-english.pdf', 'pdfs/vol_48_no_01-english.pdf', 'pdfs/vol_47_no_01-english.pdf', 'pdfs/vol_46_no_01-english.pdf', 'pdfs/vol_45_no_01-english.pdf', 'pdfs/vol_44_no_01-english.pdf', 'pdfs/vol_43_no_01-english.pdf', 'pdfs/vol_42_no_01-english.pdf', 'pdfs/vol_41_no_01-english.pdf', 'pdfs/vol_40_no_01_english.pdf', 'pdfs/Vol 39 NO 01 English.pdf', 'pdfs/Vol 38 NO 01 English.pdf', 'pdfs/vol_37_no_01_english.pdf', 'pdfs/Vol_36_NO_01_English.pdf', 'pdfs/vol_35_no_01_english.pdf', 'pdfs/vol_34_no_01_english.pdf']

# %%
pdf_paths.pop()
print(pdf_paths)
# Out:
# ['pdfs/en_66b1cf8a4ad9f_Vol_51_no_29-english.pdf', 'pdfs/en_65b8d3689b762_Vol_51_no_01-english.pdf', 'pdfs/en_640feff0076ea_Vol_50_no_01-english.pdf', 'pdfs/vol_49_no_01-english.pdf', 'pdfs/vol_48_no_01-english.pdf', 'pdfs/vol_47_no_01-english.pdf', 'pdfs/vol_46_no_01-english.pdf', 'pdfs/vol_45_no_01-english.pdf', 'pdfs/vol_44_no_01-english.pdf', 'pdfs/vol_43_no_01-english.pdf', 'pdfs/vol_42_no_01-english.pdf', 'pdfs/vol_41_no_01-english.pdf', 'pdfs/vol_40_no_01_english.pdf', 'pdfs/Vol 39 NO 01 English.pdf', 'pdfs/Vol 38 NO 01 English.pdf', 'pdfs/vol_37_no_01_english.pdf', 'pdfs/Vol_36_NO_01_English.pdf', 'pdfs/vol_35_no_01_english.pdf']

# %%
table_title = 'Selected notifiable diseases reported by Medical Officers of Health'

# %%
unrotated_pdfs = pdf_paths[12:19][::-1]
unrotated_pdfs
# Out:
# ['pdfs/vol_35_no_01_english.pdf',
#  'pdfs/Vol_36_NO_01_English.pdf',
#  'pdfs/vol_37_no_01_english.pdf',
#  'pdfs/Vol 38 NO 01 English.pdf',
#  'pdfs/Vol 39 NO 01 English.pdf',
#  'pdfs/vol_40_no_01_english.pdf']

# %%
import requests
from bs4 import BeautifulSoup
import os
import pdfplumber
import pandas as pd


def extract_table_from_pdf(pdf_path,table_title):
    with pdfplumber.open(pdf_path) as pdf:
        for page in pdf.pages:
            text = page.extract_text()
            if table_title in text:
                # Extract tables
                tables = page.extract_tables()
                print('table found')

                 # Initialize an empty DataFrame to hold combined data
                combined_data = pd.DataFrame()

                for table in tables:
                    df = pd.DataFrame(table[1:], columns=table[0])

                    # Check for column existence and set up the DataFrame appropriately
                    if 'DPDHS\nDivision' in df.columns:
                        df = df.iloc[1:27, 12]  # Skip the first row, which might be a header
                    else:
                        df = df.iloc[3:29, 12]  # Skip the first few rows if no 'DPDHS\nDivision' column

                    df.reset_index(drop=True, inplace=True)

                    #combined_data.rename(columns={df.columns[0]: 'Total'}, inplace=True)

                    # Add data to the combined_data DataFrame
                    combined_data =  pd.concat([combined_data, df], ignore_index=True, sort=False)



                return combined_data  # Return the combined data

    return None  # Return None if no matching table is foun

# %%
# Initialize an empty DataFrame to store all combined data
all_combined_data = pd.DataFrame()

# Iterate over the list of PDF paths
for pdf_path in unrotated_pdfs:
    extracted_data = extract_table_from_pdf(pdf_path, table_title)
    if extracted_data is not None:
        all_combined_data = pd.concat([all_combined_data, extracted_data], ignore_index=True, sort=False)

        print(f"Extracted data from {pdf_path}:")
        print(extracted_data)
    else:
        print(f"No matching table found in {pdf_path}")
# Out:
# table found
# Extracted data from pdfs/vol_35_no_01_english.pdf:
#            0
# 0   163\n311
# 1   221\n150
# 2    172\n14
# 3    169\n57
# 4    289\n00
# 5     00\n02
# 6     03\n00
# 7     00\n08
# 8     12\n87
# 9     31\n41
# 10    22\n49
# 11    56\n82
# 12   246\n02
# 13      2187
# table found
# Extracted data from pdfs/Vol_36_NO_01_English.pdf:
#                                                    0
# 0  1071\n829\n691\n537\n849\n76\n446\n142\n500\n1...
# 1                                               7406
# table found
# Extracted data from pdfs/vol_37_no_01_english.pdf:
#        0
# 0   1194
# 1    485
# 2    594
# 3    242
# 4    338
# 5     48
# 6    262
# 7    107
# 8    251
# 9      1
# 10     0
# 11     0
# 12     8
# 13     0
# 14    15
# 15    16
# 16    23
# 17   193
# 18    98
# 19   100
# 20    81
# 21   103
# 22    18
# 23   394
# 24   347
# 25     7
# table found
# Extracted data from pdfs/Vol 38 NO 01 English.pdf:
#       0
# 0   610
# 1   597
# 2   440
# 3   195
# 4   141
# 5    36
# 6   192
# 7   116
# 8   393
# 9     1
# 10    3
# 11    7
# 12    3
# 13    8
# 14   14
# 15   36
# 16   45
# 17  397
# 18   82
# 19  127
# 20  101
# 21   92
# 22   50
# 23  434
# 24  431
# 25    3
# table found
# Extracted data from pdfs/Vol 39 NO 01 English.pdf:
#        0
# 0    506
# 1    537
# 2    398
# 3    192
# 4    171
# 5     55
# 6    249
# 7    516
# 8    392
# 9      3
# 10     2
# 11    16
# 12    54
# 13     9
# 14    29
# 15    70
# 16   104
# 17  1576
# 18   125
# 19   259
# 20    87
# 21    84
# 22   194
# 23   631
# 24   367
# 25     7
# table found
# Extracted data from pdfs/vol_40_no_01_english.pdf:
#       0
# 0   226
# 1   322
# 2   301
# 3    84
# 4    50
# 5    43
# 6   147
# 7    99
# 8   213
# 9     3
# 10    4
# 11   30
# 12   19
# 13    3
# 14   12
# 15   29
# 16   43
# 17  160
# 18   42
# 19  103
# 20   74
# 21   38
# 22   76
# 23  309
# 24  194
# 25    9

# %%
all_combined_data.head()
# Out:
#           0
# 0  163\n311
# 1  221\n150
# 2   172\n14
# 3   169\n57
# 4   289\n00

# %%
all_combined_data.columns = ['Cases']

# %%
import pandas as pd

# Function to split rows with newline characters and expand them
def split_and_expand(df, col1):
    # Handle missing values by filling them with empty strings
    df[col1] = df[col1].fillna('None')  # Fill NaN values with empty strings

    # Filter rows that contain newline characters
    mask = df[col1].str.contains('\n')

    # Split and expand only the rows with newline characters
    expanded_rows = df[mask].apply(lambda x: pd.Series(x[col1].split('\n')), axis=1).stack().reset_index(level=1, drop=True).rename(col1)

    # Combine the expanded data into a new DataFrame
    expanded_df = pd.DataFrame({col1: expanded_rows}).reset_index(drop=True)

    # Append the rows that did not need expansion
    non_expanded_df = df[~mask].reset_index(drop=True)

    # Concatenate expanded and non-expanded DataFrames
    cleaned_df = pd.concat([expanded_df, non_expanded_df], ignore_index=True)

    return cleaned_df

# Clean the dataset
unrotated_combined_data = split_and_expand(all_combined_data.copy(), 'Cases')  # Create a copy to avoid modifying the original

# Display the cleaned DataFrame
print(unrotated_combined_data)
# Out:
#     Cases
# 0     163
# 1     311
# 2     221
# 3     150
# 4     172
# ..    ...
# 153    38
# 154    76
# 155   309
# 156   194
# 157     9
#
# [158 rows x 1 columns]

# %%
# Drop rows 26 and 52
unrotated_combined_data = unrotated_combined_data.drop([52, 53])

# Reset the index after dropping rows
unrotated_combined_data = unrotated_combined_data.reset_index(drop=True)

# Display the modified DataFrame
print(unrotated_combined_data)
# Out:
#     Cases
# 0     163
# 1     311
# 2     221
# 3     150
# 4     172
# ..    ...
# 151    38
# 152    76
# 153   309
# 154   194
# 155     9
#
# [156 rows x 1 columns]

# %%
import pandas as pd

def split_into_columns(df, num_rows_per_column):
    # Calculate the number of columns needed
    num_columns = (len(df) + num_rows_per_column - 1) // num_rows_per_column

    # Initialize a list to hold the columns
    columns = []

    for i in range(num_columns):
        # Slice the DataFrame to get the desired rows for this column
        column_data = unrotated_combined_data.iloc[i*num_rows_per_column:(i+1)*num_rows_per_column].reset_index(drop=True)

        # Append the series as a new column
        columns.append(column_data)

    # Concatenate the columns to form the final DataFrame
    final_df = pd.concat(columns, axis=1)

    return final_df


# Split the DataFrame into columns with 25 rows each
unrotated_final_df = split_into_columns(unrotated_combined_data['Cases'], 26)



# Print the final DataFrame
print(unrotated_final_df)
# Out:
#    Cases Cases Cases Cases Cases Cases
# 0    163  1071  1194   610   506   226
# 1    311   829   485   597   537   322
# 2    221   691   594   440   398   301
# 3    150   537   242   195   192    84
# 4    172   849   338   141   171    50
# 5     14    76    48    36    55    43
# 6    169   446   262   192   249   147
# 7     57   142   107   116   516    99
# 8    289   500   251   393   392   213
# 9     00     1     1     1     3     3
# 10    00     2     0     3     2     4
# 11    02     0     0     7    16    30
# 12    03     6     8     3    54    19
# 13    00     0     0     8     9     3
# 14    00    12    15    14    29    12
# 15    08    27    16    36    70    29
# 16    12    34    23    45   104    43
# 17    87   695   193   397  1576   160
# 18    31    69    98    82   125    42
# 19    41   270   100   127   259   103
# 20    22   111    81   101    87    74
# 21    49    74   103    92    84    38
# 22    56   104    18    50   194    76
# 23    82   262   394   434   631   309
# 24   246   594   347   431   367   194
# 25    02     4     7     3     7     9

# %%
# !pip install pdf2image pillow pdfplumber
# !apt-get install poppler-utils
# Out:
# Collecting pdf2image
#   Downloading pdf2image-1.17.0-py3-none-any.whl.metadata (6.2 kB)
# Requirement already satisfied: pillow in /usr/local/lib/python3.10/dist-packages (9.4.0)
# Requirement already satisfied: pdfplumber in /usr/local/lib/python3.10/dist-packages (0.11.3)
# Requirement already satisfied: pdfminer.six==20231228 in /usr/local/lib/python3.10/dist-packages (from pdfplumber) (20231228)
# Requirement already satisfied: pypdfium2>=4.18.0 in /usr/local/lib/python3.10/dist-packages (from pdfplumber) (4.30.0)
# Requirement already satisfied: charset-normalizer>=2.0.0 in /usr/local/lib/python3.10/dist-packages (from pdfminer.six==20231228->pdfplumber) (3.3.2)
# Requirement already satisfied: cryptography>=36.0.0 in /usr/local/lib/python3.10/dist-packages (from pdfminer.six==20231228->pdfplumber) (42.0.8)
# Requirement already satisfied: cffi>=1.12 in /usr/local/lib/python3.10/dist-packages (from cryptography>=36.0.0->pdfminer.six==20231228->pdfplumber) (1.16.0)
# Requirement already satisfied: pycparser in /usr/local/lib/python3.10/dist-packages (from cffi>=1.12->cryptography>=36.0.0->pdfminer.six==20231228->pdfplumber) (2.22)
# Downloading pdf2image-1.17.0-py3-none-any.whl (11 kB)
# Installing collected packages: pdf2image
# Successfully installed pdf2image-1.17.0
# Reading package lists... Done
# Building dependency tree... Done
# Reading state information... Done
# The following NEW packages will be installed:
#   poppler-utils
# 0 upgraded, 1 newly installed, 0 to remove and 45 not upgraded.
# Need to get 186 kB of archives.
# After this operation, 696 kB of additional disk space will be used.
# Get:1 http://archive.ubuntu.com/ubuntu jammy-updates/main amd64 poppler-utils amd64 22.02.0-2ubuntu0.5 [186 kB]
# Fetched 186 kB in 2s (124 kB/s)
# Selecting previously unselected package poppler-utils.
# (Reading database ... 123598 files and directories currently installed.)
# Preparing to unpack .../poppler-utils_22.02.0-2ubuntu0.5_amd64.deb ...
# Unpacking poppler-utils (22.02.0-2ubuntu0.5) ...
# Setting up poppler-utils (22.02.0-2ubuntu0.5) ...
# Processing triggers for man-db (2.10.2-1) ...

# %%
from pdf2image import convert_from_path
from PIL import Image
import pdfplumber
import pandas as pd

def rotate_image(image_path, angle):
    with Image.open(image_path) as img:
        rotated_img = img.rotate(angle, expand=True)
        rotated_img.save('rotated_image.png')

def extract_table_from_pdf(pdf_path, table_title):
    # Convert PDF page to image
    images = convert_from_path(pdf_path, first_page=1, last_page=1)
    images[0].save('page_image.png')

    # Rotate the image if needed (e.g., 90 degrees)
    rotate_image('page_image.png', 90)

    # Use pdfplumber on the rotated image
    with pdfplumber.open(pdf_path) as pdf:
        for page in pdf.pages:
            text = page.extract_text()
            if table_title in text:
                tables = page.extract_tables()
                print('Table found')

                # Initialize an empty DataFrame to hold combined data
                combined_data = pd.DataFrame()

                for table in tables:
                    df = pd.DataFrame(table[1:], columns=table[0])
                    df = df.applymap(lambda x: ''.join(x.split())[::-1] if isinstance(x, str) else x)

                    # Check for column existence and set up the DataFrame appropriately
                    if pdf_path=='pdfs/en_66b1cf8a4ad9f_Vol_51_no_29-english.pdf':
                        df = df.iloc[15, 2:28]  # Skip the first row, which might be a header
                    else:
                        df = df.iloc[13, 2:28]  # Skip the first few rows if no 'DPDHS\nDivision' column

                    df.reset_index(drop=True, inplace=True)

                    # Add data to the combined_data DataFrame
                    combined_data = pd.concat([combined_data, df], ignore_index=True, sort=False)

                return combined_data  # Return the combined data

    return None  # Return None if no matching table is found

# %%
rotated_paths = pdf_paths[0:12][::-1]
rotated_paths
# Out:
# ['pdfs/vol_41_no_01-english.pdf',
#  'pdfs/vol_42_no_01-english.pdf',
#  'pdfs/vol_43_no_01-english.pdf',
#  'pdfs/vol_44_no_01-english.pdf',
#  'pdfs/vol_45_no_01-english.pdf',
#  'pdfs/vol_46_no_01-english.pdf',
#  'pdfs/vol_47_no_01-english.pdf',
#  'pdfs/vol_48_no_01-english.pdf',
#  'pdfs/vol_49_no_01-english.pdf',
#  'pdfs/en_640feff0076ea_Vol_50_no_01-english.pdf',
#  'pdfs/en_65b8d3689b762_Vol_51_no_01-english.pdf',
#  'pdfs/en_66b1cf8a4ad9f_Vol_51_no_29-english.pdf']

# %%
# Initialize an empty DataFrame to store all combined data
rotated_combined_data = pd.DataFrame()

# Iterate over the list of PDF paths
for pdf_path in rotated_paths:
    extracted_data = extract_table_from_pdf(pdf_path, table_title)
    if extracted_data is not None:
        rotated_combined_data = pd.concat([rotated_combined_data, extracted_data], ignore_index=True, sort=False)

        print(f"Extracted data from {pdf_path}:")
        print(extracted_data)
    else:
        print(f"No matching table found in {pdf_path}")

# Output the combined data from all PDFs
print("Rotated combined data:")
print(rotated_combined_data)
# Out:
# Table found
# Extracted data from pdfs/vol_41_no_01-english.pdf:
#       0
# 0   220
# 1   488
# 2   450
# 3    97
# 4    75
# 5    34
# 6   261
# 7   181
# 8   175
# 9    10
# 10    9
# 11   15
# 12   51
# 13   38
# 14   44
# 15   44
# 16   61
# 17  394
# 18   49
# 19  343
# 20  185
# 21   63
# 22  211
# 23  421
# 24  309
# 25   11
# <ipython-input-16-de6febcc0eef>:32: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   df = df.applymap(lambda x: ''.join(x.split())[::-1] if isinstance(x, str) else x)
# Table found
# Extracted data from pdfs/vol_42_no_01-english.pdf:
#       0
# 0   223
# 1   459
# 2   375
# 3    84
# 4    47
# 5    36
# 6   243
# 7    96
# 8   128
# 9    17
# 10    1
# 11    4
# 12   10
# 13   11
# 14   17
# 15   24
# 16   20
# 17  158
# 18   65
# 19  176
# 20   85
# 21   56
# 22  107
# 23  460
# 24  310
# 25    3
# <ipython-input-16-de6febcc0eef>:32: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   df = df.applymap(lambda x: ''.join(x.split())[::-1] if isinstance(x, str) else x)
# Table found
# Extracted data from pdfs/vol_43_no_01-english.pdf:
#       0
# 0   315
# 1   434
# 2   430
# 3   133
# 4    65
# 5    53
# 6   289
# 7   172
# 8   269
# 9    21
# 10    2
# 11    9
# 12   20
# 13   13
# 14   34
# 15   23
# 16   18
# 17  366
# 18   48
# 19  396
# 20  159
# 21   92
# 22  200
# 23  408
# 24  349
# 25   13
# <ipython-input-16-de6febcc0eef>:32: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   df = df.applymap(lambda x: ''.join(x.split())[::-1] if isinstance(x, str) else x)
# Table found
# Extracted data from pdfs/vol_44_no_01-english.pdf:
#       0
# 0   292
# 1   335
# 2   432
# 3   118
# 4    91
# 5    70
# 6   369
# 7   106
# 8   209
# 9    24
# 10   17
# 11   11
# 12   19
# 13   28
# 14   54
# 15   26
# 16   40
# 17  171
# 18   53
# 19  274
# 20   91
# 21  134
# 22  175
# 23  634
# 24  187
# 25   22
# <ipython-input-16-de6febcc0eef>:32: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   df = df.applymap(lambda x: ''.join(x.split())[::-1] if isinstance(x, str) else x)
# Table found
# Extracted data from pdfs/vol_45_no_01-english.pdf:
#       0
# 0   194
# 1   118
# 2   457
# 3    64
# 4    38
# 5    55
# 6   527
# 7    70
# 8   288
# 9    38
# 10    6
# 11    3
# 12   33
# 13   29
# 14   35
# 15   28
# 16   43
# 17  121
# 18   29
# 19  131
# 20   86
# 21  157
# 22  207
# 23  622
# 24  243
# 25   10
# <ipython-input-16-de6febcc0eef>:32: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   df = df.applymap(lambda x: ''.join(x.split())[::-1] if isinstance(x, str) else x)
# Table found
# Extracted data from pdfs/vol_46_no_01-english.pdf:
#       0
# 0   241
# 1   233
# 2   712
# 3   124
# 4   119
# 5    54
# 6   436
# 7    93
# 8   292
# 9    22
# 10   13
# 11    1
# 12   52
# 13   14
# 14   63
# 15   71
# 16   64
# 17  373
# 18   59
# 19  251
# 20  192
# 21  189
# 22  422
# 23  776
# 24  368
# 25   15
# <ipython-input-16-de6febcc0eef>:32: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   df = df.applymap(lambda x: ''.join(x.split())[::-1] if isinstance(x, str) else x)
# Table found
# Extracted data from pdfs/vol_47_no_01-english.pdf:
#        0
# 0    301
# 1    153
# 2    666
# 3    113
# 4     58
# 5     67
# 6    557
# 7    274
# 8    543
# 9     43
# 10    23
# 11     2
# 12    59
# 13    28
# 14    54
# 15    63
# 16    27
# 17   335
# 18    61
# 19   231
# 20   119
# 21   255
# 22   189
# 23  1205
# 24   340
# 25    37
# <ipython-input-16-de6febcc0eef>:32: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   df = df.applymap(lambda x: ''.join(x.split())[::-1] if isinstance(x, str) else x)
# Table found
# Extracted data from pdfs/vol_48_no_01-english.pdf:
#        0
# 0    425
# 1    314
# 2   1113
# 3    336
# 4    135
# 5    141
# 6   1214
# 7    288
# 8    624
# 9     38
# 10    26
# 11    12
# 12    53
# 13    33
# 14    40
# 15   116
# 16    32
# 17   334
# 18    74
# 19   365
# 20   175
# 21   413
# 22     0
# 23  1591
# 24   662
# 25    25
# <ipython-input-16-de6febcc0eef>:32: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   df = df.applymap(lambda x: ''.join(x.split())[::-1] if isinstance(x, str) else x)
# Table found
# Extracted data from pdfs/vol_49_no_01-english.pdf:
#       0
# 0   236
# 1   337
# 2   729
# 3   298
# 4    95
# 5    73
# 6   788
# 7   290
# 8   359
# 9    33
# 10   60
# 11   32
# 12   25
# 13   35
# 14   57
# 15   86
# 16    5
# 17  573
# 18   34
# 19  272
# 20  156
# 21  342
# 22  453
# 23  919
# 24  648
# 25   22
# <ipython-input-16-de6febcc0eef>:32: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   df = df.applymap(lambda x: ''.join(x.split())[::-1] if isinstance(x, str) else x)
# Table found
# Extracted data from pdfs/en_640feff0076ea_Vol_50_no_01-english.pdf:
#        0
# 0    293
# 1    421
# 2    569
# 3    217
# 4    141
# 5     97
# 6    637
# 7    338
# 8    368
# 9     28
# 10    15
# 11    45
# 12    35
# 13    46
# 14    81
# 15   138
# 16    42
# 17   363
# 18    85
# 19   301
# 20   184
# 21   276
# 22   359
# 23  1156
# 24   715
# 25    34
# <ipython-input-16-de6febcc0eef>:32: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   df = df.applymap(lambda x: ''.join(x.split())[::-1] if isinstance(x, str) else x)
# Table found
# Extracted data from pdfs/en_65b8d3689b762_Vol_51_no_01-english.pdf:
#        0
# 0    383
# 1    642
# 2    927
# 3    316
# 4    159
# 5    204
# 6   1020
# 7    420
# 8    556
# 9     23
# 10    13
# 11    41
# 12    59
# 13    55
# 14   125
# 15   189
# 16   114
# 17   575
# 18   151
# 19   377
# 20   264
# 21   389
# 22   648
# 23  1422
# 24   791
# 25    64
# <ipython-input-16-de6febcc0eef>:32: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   df = df.applymap(lambda x: ''.join(x.split())[::-1] if isinstance(x, str) else x)
# Table found
# Extracted data from pdfs/en_66b1cf8a4ad9f_Vol_51_no_29-english.pdf:
#        0
# 0    288
# 1    412
# 2    444
# 3    161
# 4     67
# 5    119
# 6    464
# 7    318
# 8    287
# 9     15
# 10    17
# 11    21
# 12    69
# 13    59
# 14    52
# 15   141
# 16   125
# 17   401
# 18   156
# 19   292
# 20   192
# 21   351
# 22   534
# 23  1086
# 24   438
# 25    53
# Rotated combined data:
#         0
# 0     220
# 1     488
# 2     450
# 3      97
# 4      75
# ..    ...
# 307   351
# 308   534
# 309  1086
# 310   438
# 311    53
#
# [312 rows x 1 columns]
# <ipython-input-16-de6febcc0eef>:32: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   df = df.applymap(lambda x: ''.join(x.split())[::-1] if isinstance(x, str) else x)

# %%
rotated_combined_data.columns = ['Cases']

# %%
# Clean the dataset
rotated_combined_data = split_and_expand(rotated_combined_data.copy(), 'Cases')  # Create a copy to avoid modifying the original

# Display the cleaned DataFrame
print(rotated_combined_data)
# Out:
#     Cases
# 0     220
# 1     488
# 2     450
# 3      97
# 4      75
# ..    ...
# 307   351
# 308   534
# 309  1086
# 310   438
# 311    53
#
# [312 rows x 1 columns]

# %%
rotated_combined_data.head()
# Out:
#   Cases
# 0   220
# 1   488
# 2   450
# 3    97
# 4    75

# %%
import pandas as pd

def split_into_columns(df, num_rows_per_column):
    # Calculate the number of columns needed
    num_columns = (len(df) + num_rows_per_column - 1) // num_rows_per_column

    # Initialize a list to hold the columns
    columns = []

    for i in range(num_columns):
        # Slice the DataFrame to get the desired rows for this column
        column_data = rotated_combined_data.iloc[i*num_rows_per_column:(i+1)*num_rows_per_column].reset_index(drop=True)

        # Append the series as a new column
        columns.append(column_data)

    # Concatenate the columns to form the final DataFrame
    final_df = pd.concat(columns, axis=1)

    return final_df


# Split the DataFrame into columns with 25 rows each
rotated_final_df = split_into_columns(rotated_combined_data['Cases'], 26)


# Print the final DataFrame
print(rotated_final_df)
# Out:
#    Cases Cases Cases Cases Cases Cases Cases Cases Cases Cases Cases Cases
# 0    220   223   315   292   194   241   301   425   236   293   383   288
# 1    488   459   434   335   118   233   153   314   337   421   642   412
# 2    450   375   430   432   457   712   666  1113   729   569   927   444
# 3     97    84   133   118    64   124   113   336   298   217   316   161
# 4     75    47    65    91    38   119    58   135    95   141   159    67
# 5     34    36    53    70    55    54    67   141    73    97   204   119
# 6    261   243   289   369   527   436   557  1214   788   637  1020   464
# 7    181    96   172   106    70    93   274   288   290   338   420   318
# 8    175   128   269   209   288   292   543   624   359   368   556   287
# 9     10    17    21    24    38    22    43    38    33    28    23    15
# 10     9     1     2    17     6    13    23    26    60    15    13    17
# 11    15     4     9    11     3     1     2    12    32    45    41    21
# 12    51    10    20    19    33    52    59    53    25    35    59    69
# 13    38    11    13    28    29    14    28    33    35    46    55    59
# 14    44    17    34    54    35    63    54    40    57    81   125    52
# 15    44    24    23    26    28    71    63   116    86   138   189   141
# 16    61    20    18    40    43    64    27    32     5    42   114   125
# 17   394   158   366   171   121   373   335   334   573   363   575   401
# 18    49    65    48    53    29    59    61    74    34    85   151   156
# 19   343   176   396   274   131   251   231   365   272   301   377   292
# 20   185    85   159    91    86   192   119   175   156   184   264   192
# 21    63    56    92   134   157   189   255   413   342   276   389   351
# 22   211   107   200   175   207   422   189     0   453   359   648   534
# 23   421   460   408   634   622   776  1205  1591   919  1156  1422  1086
# 24   309   310   349   187   243   368   340   662   648   715   791   438
# 25    11     3    13    22    10    15    37    25    22    34    64    53

# %%
complete_df=unrotated_final_df.merge(rotated_final_df, left_index=True, right_index=True)
print(complete_df)
# Out:
#    Cases_x Cases_x Cases_x Cases_x Cases_x Cases_x Cases_y Cases_y Cases_y  \
# 0      163    1071    1194     610     506     226     220     223     315
# 1      311     829     485     597     537     322     488     459     434
# 2      221     691     594     440     398     301     450     375     430
# 3      150     537     242     195     192      84      97      84     133
# 4      172     849     338     141     171      50      75      47      65
# 5       14      76      48      36      55      43      34      36      53
# 6      169     446     262     192     249     147     261     243     289
# 7       57     142     107     116     516      99     181      96     172
# 8      289     500     251     393     392     213     175     128     269
# 9       00       1       1       1       3       3      10      17      21
# 10      00       2       0       3       2       4       9       1       2
# 11      02       0       0       7      16      30      15       4       9
# 12      03       6       8       3      54      19      51      10      20
# 13      00       0       0       8       9       3      38      11      13
# 14      00      12      15      14      29      12      44      17      34
# 15      08      27      16      36      70      29      44      24      23
# 16      12      34      23      45     104      43      61      20      18
# 17      87     695     193     397    1576     160     394     158     366
# 18      31      69      98      82     125      42      49      65      48
# 19      41     270     100     127     259     103     343     176     396
# 20      22     111      81     101      87      74     185      85     159
# 21      49      74     103      92      84      38      63      56      92
# 22      56     104      18      50     194      76     211     107     200
# 23      82     262     394     434     631     309     421     460     408
# 24     246     594     347     431     367     194     309     310     349
# 25      02       4       7       3       7       9      11       3      13
#
#    Cases_y Cases_y Cases_y Cases_y Cases_y Cases_y Cases_y Cases_y Cases_y
# 0      292     194     241     301     425     236     293     383     288
# 1      335     118     233     153     314     337     421     642     412
# 2      432     457     712     666    1113     729     569     927     444
# 3      118      64     124     113     336     298     217     316     161
# 4       91      38     119      58     135      95     141     159      67
# 5       70      55      54      67     141      73      97     204     119
# 6      369     527     436     557    1214     788     637    1020     464
# 7      106      70      93     274     288     290     338     420     318
# 8      209     288     292     543     624     359     368     556     287
# 9       24      38      22      43      38      33      28      23      15
# 10      17       6      13      23      26      60      15      13      17
# 11      11       3       1       2      12      32      45      41      21
# 12      19      33      52      59      53      25      35      59      69
# 13      28      29      14      28      33      35      46      55      59
# 14      54      35      63      54      40      57      81     125      52
# 15      26      28      71      63     116      86     138     189     141
# 16      40      43      64      27      32       5      42     114     125
# 17     171     121     373     335     334     573     363     575     401
# 18      53      29      59      61      74      34      85     151     156
# 19     274     131     251     231     365     272     301     377     292
# 20      91      86     192     119     175     156     184     264     192
# 21     134     157     189     255     413     342     276     389     351
# 22     175     207     422     189       0     453     359     648     534
# 23     634     622     776    1205    1591     919    1156    1422    1086
# 24     187     243     368     340     662     648     715     791     438
# 25      22      10      15      37      25      22      34      64      53

# %%
Countries = ['Colombo','Gampaha','Kalutara','Kandy','Matale','Nuwara Eliya','Galle','Hambantota','Matara','Jaffna','Kilinochchi','Mannar','Vavuniya','Mullaitivu','Batticaloa','Ampara','Trincomalee',
             'Kurunegala','Puttalam','Anuradhapura','Polonnaruwa','Badulla','Monaragala','Ratnapura','Kegalle','Kalmunai']

complete_df.index = Countries
complete_df.head()
# Out:
#          Cases_x Cases_x Cases_x Cases_x Cases_x Cases_x Cases_y Cases_y  \
# Colombo      163    1071    1194     610     506     226     220     223
# Gampaha      311     829     485     597     537     322     488     459
# Kalutara     221     691     594     440     398     301     450     375
# Kandy        150     537     242     195     192      84      97      84
# Matale       172     849     338     141     171      50      75      47
#
#          Cases_y Cases_y Cases_y Cases_y Cases_y Cases_y Cases_y Cases_y  \
# Colombo      315     292     194     241     301     425     236     293
# Gampaha      434     335     118     233     153     314     337     421
# Kalutara     430     432     457     712     666    1113     729     569
# Kandy        133     118      64     124     113     336     298     217
# Matale        65      91      38     119      58     135      95     141
#
#          Cases_y Cases_y
# Colombo      383     288
# Gampaha      642     412
# Kalutara     927     444
# Kandy        316     161
# Matale       159      67

# %%
complete_df.columns = ['2007','2008','2009','2010','2011','2012','2013','2014','2015','2016','2017','2018','2019','2020','2021','2022','2023','2024']
complete_df.head()
# Out:
#          2007  2008  2009 2010 2011 2012 2013 2014 2015 2016 2017 2018 2019  \
# Colombo   163  1071  1194  610  506  226  220  223  315  292  194  241  301
# Gampaha   311   829   485  597  537  322  488  459  434  335  118  233  153
# Kalutara  221   691   594  440  398  301  450  375  430  432  457  712  666
# Kandy     150   537   242  195  192   84   97   84  133  118   64  124  113
# Matale    172   849   338  141  171   50   75   47   65   91   38  119   58
#
#           2020 2021 2022 2023 2024
# Colombo    425  236  293  383  288
# Gampaha    314  337  421  642  412
# Kalutara  1113  729  569  927  444
# Kandy      336  298  217  316  161
# Matale     135   95  141  159   67

# %%
# Reshape the DataFrame from wide to long format
df_long = pd.melt(complete_df.reset_index(), id_vars=['index'], var_name='Year', value_name='Cases')

# Rename the 'index' column to 'Country'
df_long = df_long.rename(columns={'index': 'Country'})

# Sort the DataFrame first by Year, then by Country
df_long = df_long.sort_values(by=['Year', 'Country']).reset_index(drop=True)

# Display the transformed DataFrame
print(df_long)
# Out:
#           Country  Year Cases
# 0          Ampara  2007    08
# 1    Anuradhapura  2007    41
# 2         Badulla  2007    49
# 3      Batticaloa  2007    00
# 4         Colombo  2007   163
# ..            ...   ...   ...
# 463   Polonnaruwa  2024   192
# 464      Puttalam  2024   156
# 465     Ratnapura  2024  1086
# 466   Trincomalee  2024   125
# 467      Vavuniya  2024    69
#
# [468 rows x 3 columns]

# %%
df_long.to_csv('Leptospirosis_SriLanka.csv', index=False)  # Save DataFrame to CSV

# Download the CSV file
from google.colab import files
files.download('Leptospirosis_SriLanka.csv')
